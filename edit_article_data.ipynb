# %%
def make_file_name(year,month):
    if month < 10:
        date = str(year) + '0' + str(month)
    else: 
        date = str(year) + str(month)
    return 'Article_부동산_'+ date + '_' + date

def make_data_set(s_year, s_month, e_year, e_month):
    columns_name = ['date','cat','co','headLine','content','link']
    for year in range(s_year,e_year+1):
        for month in range(s_month,e_month+1):
            path = './output/'
            file_name = make_file_name(year,month)
            df = pd.read_csv(path + file_name + '.csv', names = columns_name, encoding='CP949')
            display(df)

# %%
import pandas as pd
import matplotlib.pyplot as plt

make_data_set(2006,1,2006,3)
# Out:
#                       date  cat      co                      headLine  \
# 0     2006.01.01. 오후 11:23  부동산    매일경제             취득세ㆍ등록세 0.5%P씩 인하
# 1     2006.01.01. 오후 11:23  부동산    매일경제           양도세 부담 덜자 하반기 매물 늘듯
# 2     2006.01.01. 오후 11:23  부동산    매일경제         서울 대치동 57평형 보유세 651만원
# 3     2006.01.01. 오후 11:23  부동산    매일경제    양도세 줄이는 방법 필요경비 증빙서류 꼭 챙기자
# 4     2006.01.01. 오후 11:23  부동산    매일경제  올해 실거래가 신고제 폭풍 이중계약서 관행 사라진다
# ...                    ...  ...     ...                           ...
# 2420   2006.01.31. 오전 8:26  부동산  헤럴드POP             현대건설 강남서 올 첫 분양몰이
# 2421   2006.01.31. 오전 8:21  부동산     SBS         설 연휴 이후 부동산 시장 판도 변화는
# 2422   2006.01.31. 오전 7:02  부동산    노컷뉴스              설 이후 부동산 시장 요동치나
# 2423   2006.01.31. 오전 3:00  부동산    세계일보               참여정부 3년 부동산값 껑충
# 2424  2006.01.31. 오전 12:58  부동산     YTN                 양도세 내느니 증여하겠다
#
#                                                 content  \
# 0     종부세와 양도세 부동산 실거래가 신고제 외에도 8ㆍ31대책으로 새해부터 달라지 는 ...
# 1     2차로 매물이 늘어나는 시기로는 올 하반기가 꼽힌다. 내년부터 시행될 1가구 2주 ...
# 2     8ㆍ31부동산종합대책이 입법 완료됨에 따라 올해 부동산시장이 요동칠 가능성이 커 지...
# 3     그 동안 양도세는 대부분 기준시가로 냈고 법정 필요경비로 취득 당시 기준시가 대 비...
# 4     부동산 실거래가 신고제도가 올해 시행되면서 모든 세금이 실거래가를 기준으로 부 과된...
# ...                                                 ...
# 2420  현대건설이 지난해 말 김포 고촌 현대아파트의 성공적 분양에 이어 올 첫 사업으로 내...
# 2421  앵커 연초부터 부동산 시장이 뒤숭숭합니다. 집값이 다시 들썩들썩이고 있는데 8.31...
# 2422  정부 대책 발표 뒤 안정세를 보이던 주택 가격이 올해들어 강남과 서초 등을 중심으로...
# 2423  노무현 정부 3년 동안 전국의 땅값과 집값이 DJ·YS 정부 때보다 수십배까지 오른...
# 2424  앵커멘트 여러채의 집을 가진 사람들에게 무거운 세금을 물려 집을 팔도록 하겠다는게 ...
#
#                                                    link
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...
# ...                                                 ...
# 2420  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2421  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2422  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2423  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2424  https://news.naver.com/main/read.nhn?mode=LSD&...
#
# [2425 rows x 6 columns]
#                       date  cat      co  \
# 0     2006.02.01. 오후 11:27  부동산    세계일보
# 1      2006.02.01. 오후 9:48  부동산    서울경제
# 2      2006.02.01. 오후 9:33  부동산  파이낸셜뉴스
# 3      2006.02.01. 오후 9:33  부동산  파이낸셜뉴스
# 4      2006.02.01. 오후 9:12  부동산  파이낸셜뉴스
# ...                    ...  ...     ...
# 2830   2006.02.28. 오전 1:51  부동산  파이낸셜뉴스
# 2831   2006.02.28. 오전 1:51  부동산  파이낸셜뉴스
# 2832   2006.02.28. 오전 1:30  부동산  파이낸셜뉴스
# 2833  2006.02.28. 오전 12:45  부동산    한국경제
# 2834  2006.02.28. 오전 12:12  부동산  파이낸셜뉴스
#
#                                      headLine  \
# 0                           강남 아파트값 지난달 1% 상승
# 1                    강남 1월 아파트값 8.31 이전 수준 회복
# 2                        與，재건축아파트 개발부담금 도입 추진
# 3                           국민주택기금 25년만에 전면개편
# 4                서울 강남 아파트값 1% 올라…9월이후 최고 상승률
# ...                                       ...
# 2830  강남 리모델링 바람，강북·수도권으로 확산재건축보다 규제·시간 제약 덜해
# 2831                   민간부문 임대주택 건설실적 저조 ‘여전’
# 2832           활성화 과제는…증축한도·면세 문제등 ‘걸림돌’ 해결해야
# 2833               해외부동산도 학군이 우선… 루티즈코리아 설문조사
# 2834                          공인중개사 시험 10월29일
#
#                                                 content  \
# 0     서울 강남지역의 1월 아파트값이 1%나 오르며 8·31 부동산 종합대책 발표 이전 ...
# 1     서울 강남지역의 지난 1월 아파트 값이 1% 올라 8ㆍ31대책 발표 이전 수준을 회...
# 2     열린우리당은 1일 재건축 아파트 시장 안정을 위해 재건축 아파트에 대해 개발이익을 ...
# 3     국민주택기금의 관리와 운영체계가 25년만에 전면 개편된다. 건설교통부는 저소득·서민...
# 4     서울 강남지역의 1월 아파트값이 1% 올라 8 31 부동산종합대책 발표 이전 수준을...
# ...                                                 ...
# 2830  서울 강북과 수도권 리모델링 움직임은 지난해 하반기부터 시작됐다. 서슬 퍼런 정부 ...
# 2831  정부가 서민주거안정을 위해 공공부문 외에도 민간부문의 임대주택 건설 활성화를 위한 ...
# 2832  서울 주요 재건축 단지들이 잇따라 리모델링으로 선회하는 등 리모델링 시장이 최근들어...
# 2833  해외 주택을 매입할 때도 자녀의 학군이 가장 중요한 기준이 되는 것으로 나타났다. ...
# 2834  건설교통부와 한국토지공사는 제17회 공인중개사 자격시험을 오는 10월29일 치르기로...
#
#                                                    link
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...
# ...                                                 ...
# 2830  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2831  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2832  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2833  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2834  https://news.naver.com/main/read.nhn?mode=LSD&...
#
# [2835 rows x 6 columns]
#                       date  cat      co  \
# 0     2006.03.01. 오후 10:51  부동산  파이낸셜뉴스
# 1     2006.03.01. 오후 10:33  부동산     한겨레
# 2      2006.03.01. 오후 9:30  부동산  파이낸셜뉴스
# 3      2006.03.01. 오후 9:30  부동산  파이낸셜뉴스
# 4      2006.03.01. 오후 9:30  부동산  파이낸셜뉴스
# ...                    ...  ...     ...
# 3547   2006.03.31. 오전 1:30  부동산  파이낸셜뉴스
# 3548  2006.03.31. 오전 12:28  부동산    쿠키뉴스
# 3549  2006.03.31. 오전 12:00  부동산    경향신문
# 3550  2006.03.31. 오전 12:00  부동산    경향신문
# 3551  2006.03.31. 오전 12:00  부동산    경향신문
#
#                                           headLine  \
# 0                              거주용 해외부동산 취득한도 완전폐지
# 1                              국외 ‘부동산 투자’ 사실상 초읽기
# 2                  전국 2만6천가구 4월 새로 입주…3월보다 4천가구 늘어
# 3     본격적 이사철 …서울·수도권 전셋값 동향，강북구 1주새 1.4% 상승…강남 주춤
# 4                        송파신도시 아파트 분양 토지 임대 조건부 방식
# ...                                            ...
# 3547                             3·30 대책 세부내용 문답풀이
# 3548              공인중개사 ‘간판실명제’도입된다…자격증 양도·양수 근절키로
# 3549                 3·30 부동산대책 강남發 집값불안  ‘초강경 대응’
# 3550             3·30 부동산대책 오른만큼 거둬들여  ‘재건축 폭리’ 쐐기
# 3551                 3·30 부동산대책 3천만원 넘으면 상승폭 따라 누진
#
#                                                 content  \
# 0     이달부터 개인들의 주거용 해외주택이나 해외 직접투자 한도가 전면 자유화된다. 해외주...
# 1     한겨레 100만달러 취득한도 폐지 환리스크 늘어 대책 필요 1일 정부의 외환거래 규...
# 2     오는 4월에는 전국적으로 80개 단지에서 총 2만6000여 가구가 입주할 예정이다....
# 3     ‘전셋값 강북권 급상승 강남권 주춤.’ 본격적인 이사철이 다가오면서 서울 및 수도권...
# 4     이해찬 국무총리가 서울 송파신도시의 아파트 분양방식과 관련해 토지 임대부 분양을 검...
# ...                                                 ...
# 3547  최근 집값 앙등의 진원인 서울 강남권 재건축아파트 시장 안정을 골자로 한 8·31 ...
# 3548  쿠키 사회 공인중개사사무소에 중개사의 이름을 내걸고 영업하는 ‘간판실명제’가 도입된...
# 3549  열린우리당 이강래 부동산기획단장 가운데 이 30일 국회 기자실에서 재건축 개발이익환...
# 3550  정부의 ‘3·30대책’ 가운데 분양가를 낮추기 위해 택지공급가 산정방식을 개선하거나...
# 3551  재건축 초과이익은 재건축 종료시점 즉 준공시점의 주택가격에서 착수시점 재건축 추진위...
#
#                                                    link
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...
# ...                                                 ...
# 3547  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3548  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3549  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3550  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3551  https://news.naver.com/main/read.nhn?mode=LSD&...
#
# [3552 rows x 6 columns]

# %%
frame
# Out:
#                       0    1     2                             3     \
# 0     2006.01.01. 오후 11:23  부동산  매일경제             취득세ㆍ등록세 0.5%P씩 인하
# 1     2006.01.01. 오후 11:23  부동산  매일경제           양도세 부담 덜자 하반기 매물 늘듯
# 2     2006.01.01. 오후 11:23  부동산  매일경제         서울 대치동 57평형 보유세 651만원
# 3     2006.01.01. 오후 11:23  부동산  매일경제    양도세 줄이는 방법 필요경비 증빙서류 꼭 챙기자
# 4     2006.01.01. 오후 11:23  부동산  매일경제  올해 실거래가 신고제 폭풍 이중계약서 관행 사라진다
# ...                    ...  ...   ...                           ...
# 9654                   NaN  NaN   NaN                           NaN
# 9655                   NaN  NaN   NaN                           NaN
# 9656                   NaN  NaN   NaN                           NaN
# 9657                   NaN  NaN   NaN                           NaN
# 9658                   NaN  NaN   NaN                           NaN
#
#                                                    4     \
# 0     종부세와 양도세 부동산 실거래가 신고제 외에도 8ㆍ31대책으로 새해부터 달라지 는 ...
# 1     2차로 매물이 늘어나는 시기로는 올 하반기가 꼽힌다. 내년부터 시행될 1가구 2주 ...
# 2     8ㆍ31부동산종합대책이 입법 완료됨에 따라 올해 부동산시장이 요동칠 가능성이 커 지...
# 3     그 동안 양도세는 대부분 기준시가로 냈고 법정 필요경비로 취득 당시 기준시가 대 비...
# 4     부동산 실거래가 신고제도가 올해 시행되면서 모든 세금이 실거래가를 기준으로 부 과된...
# ...                                                 ...
# 9654                                                NaN
# 9655                                                NaN
# 9656                                                NaN
# 9657                                                NaN
# 9658                                                NaN
#
#                                                    5                    6     \
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...  2006.02.01. 오후 9:48
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...  2006.02.01. 오후 9:33
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...  2006.02.01. 오후 9:33
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...  2006.02.01. 오후 9:12
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...  2006.02.01. 오후 9:12
# ...                                                 ...                  ...
# 9654                                                NaN                  NaN
# 9655                                                NaN                  NaN
# 9656                                                NaN                  NaN
# 9657                                                NaN                  NaN
# 9658                                                NaN                  NaN
#
#      7       8                              9     ...    1070  \
# 0     부동산    서울경제       강남 1월 아파트값 8.31 이전 수준 회복  ...  디지털타임스
# 1     부동산  파이낸셜뉴스           與，재건축아파트 개발부담금 도입 추진  ...  디지털타임스
# 2     부동산  파이낸셜뉴스              국민주택기금 25년만에 전면개편  ...  디지털타임스
# 3     부동산  파이낸셜뉴스   서울 강남 아파트값 1% 올라…9월이후 최고 상승률  ...    동아일보
# 4     부동산  파이낸셜뉴스  생애첫주택자금 대출기준 강화은행선 종전대로… ‘혼선’  ...    서울경제
# ...   ...     ...                            ...  ...     ...
# 9654  NaN     NaN                            NaN  ...     NaN
# 9655  NaN     NaN                            NaN  ...     NaN
# 9656  NaN     NaN                            NaN  ...     NaN
# 9657  NaN     NaN                            NaN  ...     NaN
# 9658  NaN     NaN                            NaN  ...     NaN
#
#                                        1071  \
# 0                 LH 3400억 3년 만기 소셜본드 발행 성공
# 1         세입자 퇴거위로금 요구 빈번… 새 임대차법 원점 재검토 필요
# 2                     전월세신고제 주택시장 혼란만 가중될 것
# 3     임대차법 시행 3개월 만에…서울 아파트 전세 중위가격 5억 원 넘어
# 4          서울 6억 전세도 씨말라 가···지친 임차인들 매입 저울질
# ...                                     ...
# 9654                                    NaN
# 9655                                    NaN
# 9656                                    NaN
# 9657                                    NaN
# 9658                                    NaN
#
#                                                    1072  \
# 0     취약계층 주거안정 노력할것 한국토지주택공사 LH 진주사옥 전경. 연합뉴스 디지털타임...
# 1     洪 부총리 선례에 민심 부글 비어 있는 매물 정보란 전세 공급 부족 정도를 나타내는...
# 2     내년 6월 시행 놓고 시장 우려 정부 전월세시장 투명 만 강조 암시장 이면 계약 등...
# 3     서울 아파트 전세 중위가격이 임대차2법 시행 석 달 만에 약 4000만 원이 뛰어 ...
# 4     20년만의 최악 전세난 임대차법 시행 이후 물량 급감 대전·울산선 전셋값 억대 뛰어...
# ...                                                 ...
# 9654                                                NaN
# 9655                                                NaN
# 9656                                                NaN
# 9657                                                NaN
# 9658                                                NaN
#
#                                                    1073                 1074  \
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...  2020.12.01. 오후 8:17
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...  2020.12.01. 오후 8:09
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...  2020.12.01. 오후 8:00
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...  2020.12.01. 오후 8:00
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...  2020.12.01. 오후 7:55
# ...                                                 ...                  ...
# 9654                                                NaN                  NaN
# 9655                                                NaN                  NaN
# 9656                                                NaN                  NaN
# 9657                                                NaN                  NaN
# 9658                                                NaN                  NaN
#
#      1075    1076                                    1077  \
# 0     부동산    이데일리   국토연 “미혼 청년 주거정책으로 생애최초 특별공급의 대상 논의해야”
# 1     부동산    이데일리               송파 위례신도시 공공분양 특공에 3만여명 신청
# 2     부동산    경향신문  호텔 개조 임대주택 월세 27만35만원…입주 청년들 “나쁘지 않아요”
# 3     부동산    경향신문  호텔 개조 임대주택 월세 27만35만원…입주 청년들 “나쁘지 않아요”
# 4     부동산  디지털타임스  현미가 쌀이라면 당장 바꾸겠다…김현미 아파트 빵 발언 계속되는 후폭풍
# ...   ...     ...                                     ...
# 9654  NaN     NaN                                     NaN
# 9655  NaN     NaN                                     NaN
# 9656  NaN     NaN                                     NaN
# 9657  NaN     NaN                                     NaN
# 9658  NaN     NaN                                     NaN
#
#                                                    1078  \
# 0     이데일리 신수정 기자 국토연구원이 청년에 대한 주택공급 정책이 한정적이라고 지적 생...
# 1     이데일리 박정수 기자 송파 위례신도시 2개 블록 공공분양 특별공급에 3만명에 가까운...
# 2     서울 관광호텔 리모델링한 공유주택 ‘안암생활’ 가보니 경향신문 한국토지주택공사 LH...
# 3     서울 관광호텔 리모델링한 공유주택 ‘안암생활’ 가보니 경향신문 한국토지주택공사 LH...
# 4     디지털타임스 박상길 기자 김현미 국토교통부 장관의 아파트 빵 발언을 둘러싼 후폭풍이...
# ...                                                 ...
# 9654                                                NaN
# 9655                                                NaN
# 9656                                                NaN
# 9657                                                NaN
# 9658                                                NaN
#
#                                                    1079
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...
# ...                                                 ...
# 9654                                                NaN
# 9655                                                NaN
# 9656                                                NaN
# 9657                                                NaN
# 9658                                                NaN
#
# [9659 rows x 1080 columns]

# %%
df = pd.Datadf = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'))
df
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'))
df.append(df2)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
df.append(df2, ignore_index=True)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
df = pd.DataFrame(columns=['A'])
for i in range(5):
    df = df.append({'A': i}, ignore_index=True)
df
# Out:
#    A
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
pd.concat([pd.DataFrame([i], columns=['A']) for i in range(5)],
          ignore_index=True)
# Out:
#    A
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
columns_name = ['date','cat','co','headLine','content','link']

table = pd.DataFrame([], columns = columns_name)

for month in range(1,3):
    path = './output/'
    file_name = make_file_name(2006,month)
    df = pd.read_csv(path + file_name + '.csv', names = columns_name, encoding='CP949')
    display(df)
    display(table)
    table.append(df, ignore_index=True)
display(table)
# Out:
#                       date  cat      co                      headLine  \
# 0     2006.01.01. 오후 11:23  부동산    매일경제             취득세ㆍ등록세 0.5%P씩 인하
# 1     2006.01.01. 오후 11:23  부동산    매일경제           양도세 부담 덜자 하반기 매물 늘듯
# 2     2006.01.01. 오후 11:23  부동산    매일경제         서울 대치동 57평형 보유세 651만원
# 3     2006.01.01. 오후 11:23  부동산    매일경제    양도세 줄이는 방법 필요경비 증빙서류 꼭 챙기자
# 4     2006.01.01. 오후 11:23  부동산    매일경제  올해 실거래가 신고제 폭풍 이중계약서 관행 사라진다
# ...                    ...  ...     ...                           ...
# 2420   2006.01.31. 오전 8:26  부동산  헤럴드POP             현대건설 강남서 올 첫 분양몰이
# 2421   2006.01.31. 오전 8:21  부동산     SBS         설 연휴 이후 부동산 시장 판도 변화는
# 2422   2006.01.31. 오전 7:02  부동산    노컷뉴스              설 이후 부동산 시장 요동치나
# 2423   2006.01.31. 오전 3:00  부동산    세계일보               참여정부 3년 부동산값 껑충
# 2424  2006.01.31. 오전 12:58  부동산     YTN                 양도세 내느니 증여하겠다
#
#                                                 content  \
# 0     종부세와 양도세 부동산 실거래가 신고제 외에도 8ㆍ31대책으로 새해부터 달라지 는 ...
# 1     2차로 매물이 늘어나는 시기로는 올 하반기가 꼽힌다. 내년부터 시행될 1가구 2주 ...
# 2     8ㆍ31부동산종합대책이 입법 완료됨에 따라 올해 부동산시장이 요동칠 가능성이 커 지...
# 3     그 동안 양도세는 대부분 기준시가로 냈고 법정 필요경비로 취득 당시 기준시가 대 비...
# 4     부동산 실거래가 신고제도가 올해 시행되면서 모든 세금이 실거래가를 기준으로 부 과된...
# ...                                                 ...
# 2420  현대건설이 지난해 말 김포 고촌 현대아파트의 성공적 분양에 이어 올 첫 사업으로 내...
# 2421  앵커 연초부터 부동산 시장이 뒤숭숭합니다. 집값이 다시 들썩들썩이고 있는데 8.31...
# 2422  정부 대책 발표 뒤 안정세를 보이던 주택 가격이 올해들어 강남과 서초 등을 중심으로...
# 2423  노무현 정부 3년 동안 전국의 땅값과 집값이 DJ·YS 정부 때보다 수십배까지 오른...
# 2424  앵커멘트 여러채의 집을 가진 사람들에게 무거운 세금을 물려 집을 팔도록 하겠다는게 ...
#
#                                                    link
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...
# ...                                                 ...
# 2420  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2421  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2422  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2423  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2424  https://news.naver.com/main/read.nhn?mode=LSD&...
#
# [2425 rows x 6 columns]
# Empty DataFrame
# Columns: [date, cat, co, headLine, content, link]
# Index: []
#                       date  cat      co  \
# 0     2006.02.01. 오후 11:27  부동산    세계일보
# 1      2006.02.01. 오후 9:48  부동산    서울경제
# 2      2006.02.01. 오후 9:33  부동산  파이낸셜뉴스
# 3      2006.02.01. 오후 9:33  부동산  파이낸셜뉴스
# 4      2006.02.01. 오후 9:12  부동산  파이낸셜뉴스
# ...                    ...  ...     ...
# 2830   2006.02.28. 오전 1:51  부동산  파이낸셜뉴스
# 2831   2006.02.28. 오전 1:51  부동산  파이낸셜뉴스
# 2832   2006.02.28. 오전 1:30  부동산  파이낸셜뉴스
# 2833  2006.02.28. 오전 12:45  부동산    한국경제
# 2834  2006.02.28. 오전 12:12  부동산  파이낸셜뉴스
#
#                                      headLine  \
# 0                           강남 아파트값 지난달 1% 상승
# 1                    강남 1월 아파트값 8.31 이전 수준 회복
# 2                        與，재건축아파트 개발부담금 도입 추진
# 3                           국민주택기금 25년만에 전면개편
# 4                서울 강남 아파트값 1% 올라…9월이후 최고 상승률
# ...                                       ...
# 2830  강남 리모델링 바람，강북·수도권으로 확산재건축보다 규제·시간 제약 덜해
# 2831                   민간부문 임대주택 건설실적 저조 ‘여전’
# 2832           활성화 과제는…증축한도·면세 문제등 ‘걸림돌’ 해결해야
# 2833               해외부동산도 학군이 우선… 루티즈코리아 설문조사
# 2834                          공인중개사 시험 10월29일
#
#                                                 content  \
# 0     서울 강남지역의 1월 아파트값이 1%나 오르며 8·31 부동산 종합대책 발표 이전 ...
# 1     서울 강남지역의 지난 1월 아파트 값이 1% 올라 8ㆍ31대책 발표 이전 수준을 회...
# 2     열린우리당은 1일 재건축 아파트 시장 안정을 위해 재건축 아파트에 대해 개발이익을 ...
# 3     국민주택기금의 관리와 운영체계가 25년만에 전면 개편된다. 건설교통부는 저소득·서민...
# 4     서울 강남지역의 1월 아파트값이 1% 올라 8 31 부동산종합대책 발표 이전 수준을...
# ...                                                 ...
# 2830  서울 강북과 수도권 리모델링 움직임은 지난해 하반기부터 시작됐다. 서슬 퍼런 정부 ...
# 2831  정부가 서민주거안정을 위해 공공부문 외에도 민간부문의 임대주택 건설 활성화를 위한 ...
# 2832  서울 주요 재건축 단지들이 잇따라 리모델링으로 선회하는 등 리모델링 시장이 최근들어...
# 2833  해외 주택을 매입할 때도 자녀의 학군이 가장 중요한 기준이 되는 것으로 나타났다. ...
# 2834  건설교통부와 한국토지공사는 제17회 공인중개사 자격시험을 오는 10월29일 치르기로...
#
#                                                    link
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...
# 4     https://news.naver.com/main/read.nhn?mode=LSD&...
# ...                                                 ...
# 2830  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2831  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2832  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2833  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2834  https://news.naver.com/main/read.nhn?mode=LSD&...
#
# [2835 rows x 6 columns]
# Empty DataFrame
# Columns: [date, cat, co, headLine, content, link]
# Index: []
# Empty DataFrame
# Columns: [date, cat, co, headLine, content, link]
# Index: []
