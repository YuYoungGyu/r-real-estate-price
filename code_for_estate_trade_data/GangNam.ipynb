# %%
import pandas as pd

path = '../seoul_estate_trade_data/'

gangnam = pd.read_csv(path+'강남구.csv')

# %%
# 강남구 실거래량
district_code = get_district_code('강남구')

gangnam_count = pd.DataFrame([molit.AptTrade(district_code, make_date(year,month)).count() 
                     for year in range(2006,2020) for month in range(1,13)])

# %%
# 강남구 실거래량 그래프
import matplotlib.pyplot as plt

plt.plot(gangnam_count)

# %%
molit.AptTrade(district_code, make_date(2006,1))
# Out:
#       지역코드  법정동        거래일            아파트      지번    전용면적   층  건축년도    거래금액
# 0    11680  개포동 2006-01-02       개포주공 4단지     189   35.64   4  1982   39200
# 1    11680  개포동 2006-01-02       개포현대200동   655-1   82.20   8  1986   58000
# 2    11680  개포동 2006-01-02             시영     656   51.18   3  1984   65000
# 3    11680  개포동 2006-01-03       개포주공 1단지     141   50.64   3  1982   65700
# 4    11680  개포동 2006-01-03       개포주공 3단지     138   41.99   1  1982   62000
# ..     ...  ...        ...            ...     ...     ...  ..   ...     ...
# 691  11680  청담동 2006-01-24             한양   134-9   95.47   8  1981   99800
# 692  11680  청담동 2006-01-25    청담대림 이-편한세상   30-33   81.84  15  2002   74000
# 693  11680  청담동 2006-01-25  상지리츠빌(127-16)  127-16  165.17   1  2001   95000
# 694  11680  청담동 2006-01-31       대우로얄카운티2   116-5  243.10   3  2002  217000
# 695  11680  청담동 2006-01-31        청담삼익아파트  134-15  138.51   4  1980  156000
#
# [696 rows x 9 columns]
