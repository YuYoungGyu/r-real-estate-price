# %%
import PublicDataReader as pdr
import pandas as pd
print(pdr.__version__)

serviceKey = 'Arjt7EQRVOdUPjLvpxVjFg9RvfEbWJb%2Bd5qNQ1h%2B9Q6nF37OgOVZNqGNZy4pW8XiYeBmrSeq%2BYUOi1N%2Bn2kgYg%3D%3D'

molit = pdr.Transaction(serviceKey)
# Out:
# >>> PublicDataReader Version : 2021.1.9
#
# - Author : Wooil Jeong
# - E-mail : wooil@kakao.com
# - Github : https://github.com/WooilJeong/PublicDataReader
# - Blog : https://wooiljeong.github.io
#
# >>> 아파트매매 실거래자료 조회 서비스키 미등록 오류입니다.
# >>> 아파트매매 실거래 상세 자료 조회 서비스가 정상 작동합니다.
# >>> 아파트 전월세 자료 조회 서비스가 정상 작동합니다.
# >>> 아파트 분양권전매 신고 자료 조회 서비스가 정상 작동합니다.
# >>> 오피스텔 매매 신고 조회 서비스가 정상 작동합니다.
# >>> 오피스텔 전월세 신고 조회 서비스가 정상 작동합니다.
# >>> 연립다세대 매매 실거래자료 조회 서비스가 정상 작동합니다.
# >>> 연립다세대 전월세 실거래자료 조회 서비스가 정상 작동합니다.
# >>> 단독/다가구 매매 실거래 조회 서비스가 정상 작동합니다.
# >>> 단독/다가구 전월세 자료 조회 서비스가 정상 작동합니다.
# >>> 토지 매매 신고 조회 서비스가 정상 작동합니다.
# >>> 상업업무용 부동산 매매 신고 자료 조회 서비스가 정상 작동합니다.

# %%
def get_district_code(bdongName):
    district_name = bdongName
    codeResult = molit.CodeFinder(district_name)
    district_code = codeResult.iloc[0,1]
    return district_code

# %%
gu_name = ['강남구','강동구','강서구','강북구','관악구','광진구','구로구','금천구',
          '노원구','동대문구','도봉구','동작구','마포구','서대문구','성동구','성북구',
          '서초구','송파구','영등포구','용산구','양천구','은평구','종로구','중구','중랑구']

many = len(gu_name)

# %%
# 구 별로 dataframe 만들기
for i in range(many):
    
    district_code = get_district_code(gu_name[i])
    gu_data = molit.DataCollector(molit.AptTrade, district_code, 200601, 202012)
    
    file_name = gu_name[i]
    gu_data.to_csv(f'../seoul_estate_trade_data/{file_name}_trade.csv')
# Out:
# >>> LAWD_CD : 11680 DEAL_YMD : 200601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 200912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201101
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201102
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201103
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201104
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201105
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201106
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201107
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201108
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201109
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201110
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201111
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201112
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201201
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201202
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201203
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201204
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201205
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201206
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201207
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201208
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201209
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201210
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201211
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201212
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201301
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201302
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201303
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201304
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201305
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201306
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201307
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201308
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201309
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201310
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201311
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201312
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201401
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201402
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201403
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201404
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201405
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201406
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201407
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201408
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201409
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201410
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201411
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201412
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201501
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201502
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201503
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201504
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201505
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201506
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201507
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201508
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201509
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201510
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201511
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201512
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 201912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11680 DEAL_YMD : 202012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 200912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201101
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201102
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201103
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201104
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201105
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201106
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201107
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201108
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201109
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201110
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201111
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201112
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201201
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201202
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201203
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201204
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201205
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201206
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201207
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201208
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201209
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201210
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201211
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201212
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201301
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201302
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201303
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201304
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201305
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201306
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201307
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201308
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201309
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201310
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201311
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201312
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201401
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201402
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201403
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201404
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201405
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201406
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201407
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201408
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201409
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201410
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201411
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201412
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201501
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201502
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201503
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201504
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201505
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201506
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201507
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201508
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201509
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201510
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201511
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201512
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 201912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11740 DEAL_YMD : 202012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 200912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201101
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201102
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201103
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201104
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201105
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201106
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201107
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201108
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201109
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201110
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201111
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201112
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201201
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201202
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201203
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201204
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201205
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201206
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201207
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201208
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201209
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201210
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201211
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201212
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201301
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201302
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201303
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201304
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201305
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201306
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201307
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201308
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201309
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201310
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201311
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201312
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201401
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201402
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201403
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201404
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201405
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201406
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201407
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201408
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201409
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201410
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201411
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201412
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201501
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201502
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201503
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201504
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201505
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201506
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201507
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201508
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201509
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201510
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201511
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201512
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 201912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11500 DEAL_YMD : 202012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 200912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201101
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201102
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201103
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201104
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201105
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201106
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201107
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201108
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201109
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201110
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201111
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201112
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201201
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201202
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201203
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201204
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201205
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201206
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201207
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201208
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201209
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201210
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201211
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201212
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201301
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201302
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201303
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201304
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201305
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201306
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201307
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201308
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201309
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201310
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201311
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201312
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201401
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201402
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201403
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201404
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201405
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201406
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201407
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201408
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201409
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201410
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201411
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201412
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201501
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201502
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201503
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201504
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201505
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201506
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201507
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201508
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201509
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201510
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201511
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201512
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 201912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11305 DEAL_YMD : 202012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 200912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201101
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201102
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201103
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201104
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201105
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201106
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201107
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201108
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201109
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201110
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201111
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201112
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201201
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201202
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201203
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201204
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201205
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201206
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201207
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201208
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201209
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201210
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201211
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201212
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201301
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201302
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201303
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201304
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201305
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201306
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201307
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201308
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201309
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201310
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201311
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201312
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201401
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201402
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201403
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201404
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201405
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201406
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201407
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201408
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201409
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201410
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201411
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201412
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201501
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201502
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201503
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201504
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201505
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201506
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201507
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201508
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201509
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201510
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201511
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201512
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 201912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11620 DEAL_YMD : 202012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11215 DEAL_YMD : 200711
# 조회할 자료가 없습니다.
# ...
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201101
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201102
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201103
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201104
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201105
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201106
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201107
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201108
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201109
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201110
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201111
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201112
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201201
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201202
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201203
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201204
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201205
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201206
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201207
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201208
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201209
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201210
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201211
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201212
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201301
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201302
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201303
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201304
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201305
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201306
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201307
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201308
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201309
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201310
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201311
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201312
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201401
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201402
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201403
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201404
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201405
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201406
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201407
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201408
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201409
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201410
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201411
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201412
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201501
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201502
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201503
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201504
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201505
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201506
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201507
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201508
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201509
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201510
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201511
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201512
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 201912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11140 DEAL_YMD : 202012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 200912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201012
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201101
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201102
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201103
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201104
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201105
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201106
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201107
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201108
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201109
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201110
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201111
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201112
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201201
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201202
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201203
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201204
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201205
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201206
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201207
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201208
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201209
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201210
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201211
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201212
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201301
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201302
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201303
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201304
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201305
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201306
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201307
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201308
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201309
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201310
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201311
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201312
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201401
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201402
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201403
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201404
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201405
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201406
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201407
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201408
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201409
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201410
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201411
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201412
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201501
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201502
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201503
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201504
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201505
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201506
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201507
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201508
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201509
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201510
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201511
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201512
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201601
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201602
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201603
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201604
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201605
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201606
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201607
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201608
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201609
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201610
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201611
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201612
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201701
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201702
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201703
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201704
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201705
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201706
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201707
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201708
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201709
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201710
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201711
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201712
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201801
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201802
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201803
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201804
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201805
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201806
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201807
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201808
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201809
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201810
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201811
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201812
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201901
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201902
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201903
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201904
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201905
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201906
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201907
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201908
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201909
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201910
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201911
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 201912
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202001
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202002
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202003
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202004
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202005
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202006
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202007
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202008
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202009
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202010
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202011
# 조회할 자료가 없습니다.
# >>> LAWD_CD : 11260 DEAL_YMD : 202012
# 조회할 자료가 없습니다.
